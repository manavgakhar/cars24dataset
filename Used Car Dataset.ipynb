# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('test-data.csv')

# %%
df2=pd.read_csv('train-data.csv')

# %%
df
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# 5              5                             Mahindra XUV500 W8 2WD
# 6              6                Toyota Fortuner 4x2 AT TRD Sportivo
# 7              7                               Hyundai EON Era Plus
# 8              8                                Honda City 1.5 S MT
# 9              9                             Mahindra XUV500 W6 2WD
# 10            10                          Audi Q5 2008-2012 2.0 TDI
# 11            11                            Hyundai Grand i10 Magna
# 12            12                                  Toyota Corolla H5
# ...

# %%
df2
# Out:
#       Unnamed: 0                                              Name  \
# 0              0                            Maruti Wagon R LXI CNG
# 1              1                  Hyundai Creta 1.6 CRDi SX Option
# 2              2                                      Honda Jazz V
# 3              3                                 Maruti Ertiga VDI
# 4              4                   Audi A4 New 2.0 TDI Multitronic
# 5              5                   Hyundai EON LPG Era Plus Option
# 6              6                            Nissan Micra Diesel XV
# 7              7                 Toyota Innova Crysta 2.8 GX AT 8S
# 8              8               Volkswagen Vento Diesel Comfortline
# 9              9                    Tata Indica Vista Quadrajet LS
# 10            10                                  Maruti Ciaz Zeta
# 11            11                       Honda City 1.5 V AT Sunroof
# 12            12                             Maruti Swift VDI BSIV
# ...

# %%
df3=pd.concat([df,df2])
# Out:
# C:\Users\manavgakhar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7253 entries, 0 to 6018
# Data columns (total 14 columns):
# Engine               7207 non-null object
# Fuel_Type            7253 non-null object
# Kilometers_Driven    7253 non-null int64
# Location             7253 non-null object
# Mileage              7251 non-null object
# Name                 7253 non-null object
# New_Price            1006 non-null object
# Owner_Type           7253 non-null object
# Power                7207 non-null object
# Price                6019 non-null float64
# Seats                7200 non-null float64
# Transmission         7253 non-null object
# Unnamed: 0           7253 non-null int64
# Year                 7253 non-null int64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 850.0+ KB

# %%
df3
# Out:
#        Engine Fuel_Type  Kilometers_Driven    Location      Mileage  \
# 0      998 CC       CNG              40929       Delhi  32.26 km/kg
# 1      796 CC    Petrol              54493  Coimbatore    24.7 kmpl
# 2     2393 CC    Diesel              34000      Mumbai   13.68 kmpl
# 3     1364 CC    Diesel             139000   Hyderabad   23.59 kmpl
# 4     1197 CC    Petrol              29000      Mumbai    18.5 kmpl
# 5     2179 CC    Diesel              85609  Coimbatore    16.0 kmpl
# 6     2982 CC    Diesel              59000        Pune   12.55 kmpl
# 7      814 CC    Petrol              65000      Jaipur    21.1 kmpl
# 8     1497 CC    Petrol              66000      Mumbai    17.0 kmpl
# 9     2179 CC    Diesel              54684  Coimbatore    15.1 kmpl
# 10    1968 CC    Diesel              78000      Mumbai    12.8 kmpl
# 11    1197 CC    Petrol              21000      Jaipur    18.9 kmpl
# 12    1794 CC    Petrol              90000     Chennai    13.4 kmpl
# ...

# %%
df3.columns
# Out:
# Index(['Engine', 'Fuel_Type', 'Kilometers_Driven', 'Location', 'Mileage',
#        'Name', 'New_Price', 'Owner_Type', 'Power', 'Price', 'Seats',
#        'Transmission', 'Unnamed: 0', 'Year'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Engine', 'Fuel_Type', 'Kilometers_Driven', 'Location', 'Mileage',
#        'Name', 'New_Price', 'Owner_Type', 'Power', 'Price', 'Seats',
#        'Transmission', 'Unnamed: 0', 'Year'],
#       dtype='object')

# %%
df3.drop(labels=['New_Price','Unnamed: 0'],inplace=True,axis=1)

# %%
df3.drop(labels='Name',axis=1,inplace=True)

# %%
df3.head()
# Out:
#     Engine Fuel_Type  Kilometers_Driven    Location      Mileage Owner_Type  \
# 0   998 CC       CNG              40929       Delhi  32.26 km/kg      First
# 1   796 CC    Petrol              54493  Coimbatore    24.7 kmpl     Second
# 2  2393 CC    Diesel              34000      Mumbai   13.68 kmpl      First
# 3  1364 CC    Diesel             139000   Hyderabad   23.59 kmpl      First
# 4  1197 CC    Petrol              29000      Mumbai    18.5 kmpl      First
#
#        Power  Price  Seats Transmission  Year
# 0   58.2 bhp    NaN    4.0       Manual  2014
# 1   47.3 bhp    NaN    5.0       Manual  2013
# 2  147.8 bhp    NaN    7.0       Manual  2017
# 3   null bhp    NaN    5.0       Manual  2012
# 4  82.85 bhp    NaN    5.0       Manual  2014

# %%
df3= df3[pd.notnull(df3['Price'])]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6019 entries, 0 to 6018
# Data columns (total 11 columns):
# Engine               5983 non-null object
# Fuel_Type            6019 non-null object
# Kilometers_Driven    6019 non-null int64
# Location             6019 non-null object
# Mileage              6017 non-null object
# Owner_Type           6019 non-null object
# Power                5983 non-null object
# Price                6019 non-null float64
# Seats                5977 non-null float64
# Transmission         6019 non-null object
# Year                 6019 non-null int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 564.3+ KB

# %%
 df3.head()
# Out:
#     Engine Fuel_Type  Kilometers_Driven    Location     Mileage Owner_Type  \
# 0   998 CC       CNG              72000      Mumbai  26.6 km/kg      First
# 1  1582 CC    Diesel              41000        Pune  19.67 kmpl      First
# 2  1199 CC    Petrol              46000     Chennai   18.2 kmpl      First
# 3  1248 CC    Diesel              87000     Chennai  20.77 kmpl      First
# 4  1968 CC    Diesel              40670  Coimbatore   15.2 kmpl     Second
#
#        Power  Price  Seats Transmission  Year
# 0  58.16 bhp   1.75    5.0       Manual  2010
# 1  126.2 bhp  12.50    5.0       Manual  2015
# 2   88.7 bhp   4.50    5.0       Manual  2011
# 3  88.76 bhp   6.00    7.0       Manual  2012
# 4  140.8 bhp  17.74    5.0    Automatic  2013

# %%
df3.dropna(inplace=True)
# Out:
# C:\Users\manavgakhar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5975 entries, 0 to 6018
# Data columns (total 11 columns):
# Engine               5975 non-null object
# Fuel_Type            5975 non-null object
# Kilometers_Driven    5975 non-null int64
# Location             5975 non-null object
# Mileage              5975 non-null object
# Owner_Type           5975 non-null object
# Power                5975 non-null object
# Price                5975 non-null float64
# Seats                5975 non-null float64
# Transmission         5975 non-null object
# Year                 5975 non-null int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 560.2+ KB

# %%
a=df3['Engine']

# %%
b=[]
for i in a:
    b.append(int(i.split(" ")[0]))

# %%
c=[]
for i in b:
    if(i==0):
        c.append(np.mean(b))
    else:
        c.append(i)

# %%
df3['Engine']=b
# Out:
# C:\Users\manavgakhar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df3['Engine'].value_counts()
# Out:
# 1197    606
# 1248    512
# 1498    303
# 998     259
# 2179    240
# 1497    229
# 1198    227
# 1968    216
# 1995    183
# 1461    152
# 2143    149
# 1582    145
# 1199    143
# 1598    141
# 1396    139
# 796     129
# 2494    121
# 1086    108
# 1591     94
# 2993     90
# 1399     88
# 2982     86
# 1798     84
# 2987     67
# 2967     61
# 814      59
# 1120     54
# 1196     50
# 1373     47
# 1364     47
#        ...
# 1242      2
# 5000      2
# 2894      2
# 2200      2
# 2706      1
# 2773      1
# 2925      1
# 2694      1
# 2349      1
# 2149      1
# 3197      1
# 1948      1
# 1978      1
# 1468      1
# 1797      1
# 1489      1
# 2487      1
# 2495      1
# 3200      1
# 2995      1
# 4951      1
# 2720      1
# 2999      1
# 970       1
# 5204      1
# 2112      1
# 2092      1
# 5998      1
# 1422      1
# 2147      1
# Name: Engine, Length: 145, dtype: int64

# %%
x=df3['Mileage']

# %%
x
# Out:
# 0       26.6 km/kg
# 1       19.67 kmpl
# 2        18.2 kmpl
# 3       20.77 kmpl
# 4        15.2 kmpl
# 5       21.1 km/kg
# 6       23.08 kmpl
# 7       11.36 kmpl
# 8       20.54 kmpl
# 9        22.3 kmpl
# 10      21.56 kmpl
# 11       16.8 kmpl
# 12       25.2 kmpl
# 13       12.7 kmpl
# 14        0.0 kmpl
# 15       13.5 kmpl
# 16       25.8 kmpl
# 17       28.4 kmpl
# 18      20.45 kmpl
# 19      14.84 kmpl
# 20      22.69 kmpl
# 21      23.65 kmpl
# 22      13.53 kmpl
# 23       18.5 kmpl
# 24       14.4 kmpl
# 25       16.8 kmpl
# 26      23.08 kmpl
# 27      20.92 kmpl
# 28       17.5 kmpl
# 29       12.8 kmpl
#            ...
# 5989    18.25 kmpl
# 5990    13.93 kmpl
# 5991     22.9 kmpl
# 5992     13.7 kmpl
# 5993     16.3 kmpl
# 5994     17.0 kmpl
# 5995    19.87 kmpl
# 5996    16.36 kmpl
# 5997    26.2 km/kg
# 5998    17.24 kmpl
# 5999    17.57 kmpl
# 6000     18.5 kmpl
# 6001    17.68 kmpl
# 6002    16.09 kmpl
# 6003     23.1 kmpl
# 6004     15.3 kmpl
# ...

# %%
y=[]
for i in x:
    y.append(float(i.split(" ")[0]))

# %%
df3['Mileage']=y
# Out:
# C:\Users\manavgakhar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df3.head()
# Out:
#    Engine Fuel_Type  Kilometers_Driven    Location  Mileage Owner_Type  \
# 0     998       CNG              72000      Mumbai    26.60      First
# 1    1582    Diesel              41000        Pune    19.67      First
# 2    1199    Petrol              46000     Chennai    18.20      First
# 3    1248    Diesel              87000     Chennai    20.77      First
# 4    1968    Diesel              40670  Coimbatore    15.20     Second
#
#        Power  Price  Seats Transmission  Year
# 0  58.16 bhp   1.75    5.0       Manual  2010
# 1  126.2 bhp  12.50    5.0       Manual  2015
# 2   88.7 bhp   4.50    5.0       Manual  2011
# 3  88.76 bhp   6.00    7.0       Manual  2012
# 4  140.8 bhp  17.74    5.0    Automatic  2013

# %%
from sklearn import preprocessing

# %%
label_encoder=preprocessing.LabelEncoder()

# %%
df3.columns
# Out:
# Index(['Engine', 'Fuel_Type', 'Kilometers_Driven', 'Location', 'Mileage',
#        'Owner_Type', 'Power', 'Price', 'Seats', 'Transmission', 'Year'],
#       dtype='object')

# %%
a=['Fuel_Type','Location','Owner_Type','Transmission']

# %%
for i in a:
    df3[i]=label_encoder.fit_transform(df3[i])
# Out:
# C:\Users\manavgakhar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df3.head()
# Out:
#    Engine  Fuel_Type  Kilometers_Driven  Location  Mileage  Owner_Type  \
# 0     998          0              72000         9    26.60           0
# 1    1582          1              41000        10    19.67           0
# 2    1199          3              46000         2    18.20           0
# 3    1248          1              87000         2    20.77           0
# 4    1968          1              40670         3    15.20           2
#
#        Power  Price  Seats  Transmission  Year
# 0  58.16 bhp   1.75    5.0             1  2010
# 1  126.2 bhp  12.50    5.0             1  2015
# 2   88.7 bhp   4.50    5.0             1  2011
# 3  88.76 bhp   6.00    7.0             1  2012
# 4  140.8 bhp  17.74    5.0             0  2013

# %%
lis=df3['Power']

# %%
liss=[]
count=0
for i in lis:
    if(i.split(' ')[0]=='null'):
        liss.append(0)
    else:
        liss.append(float(i.split(' ')[0]))

# %%
liss
# Out:
# [58.16,
#  126.2,
#  88.7,
#  88.76,
#  140.8,
#  55.2,
#  63.1,
#  171.5,
#  103.6,
#  74.0,
#  103.25,
#  116.3,
#  74.0,
#  187.7,
#  115.0,
#  175.56,
#  98.6,
#  74.0,
#  83.8,
#  167.62,
#  190.0,
#  88.5,
#  177.01,
#  80.0,
#  103.6,
#  116.3,
#  63.1,
#  67.1,
#  88.7,
#  102.0,
#  108.45,
#  138.1,
#  184.0,
#  179.5,
#  103.5,
#  64.0,
#  88.5,
#  82.0,
#  254.8,
#  73.9,
#  46.3,
#  37.5,
#  77.0,
#  82.9,
#  149.92,
#  138.03,
#  112.2,
#  163.7,
#  71.0,
#  105.0,
#  174.33,
#  74.0,
#  75.0,
#  74.0,
#  82.0,
#  103.2,
#  53.3,
#  78.9,
#  147.6,
#  67.1,
#  147.8,
#  68.0,
#  186.0,
#  170.0,
#  69.0,
#  140.0,
#  78.0,
#  194.0,
#  88.5,
#  88.7,
#  500.0,
#  140.0,
#  78.9,
#  108.5,
#  86.8,
#  187.74,
#  0,
#  132.0,
#  102.0,
#  0,
#  74.0,
#  88.7,
#  86.7,
#  68.0,
#  73.94,
#  117.3,
#  218.0,
#  78.9,
#  82.0,
#  0,
#  86.7,
#  168.5,
#  174.33,
#  89.84,
#  140.0,
#  98.6,
#  73.9,
#  110.0,
#  67.1,
#  103.5,
#  90.0,
#  82.85,
#  67.0,
#  241.4,
#  80.0,
# ...

# %%
df3['Power']=liss
# Out:
# C:\Users\manavgakhar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df3.head()
# Out:
#    Engine  Fuel_Type  Kilometers_Driven  Location  Mileage  Owner_Type  \
# 0     998          0              72000         9    26.60           0
# 1    1582          1              41000        10    19.67           0
# 2    1199          3              46000         2    18.20           0
# 3    1248          1              87000         2    20.77           0
# 4    1968          1              40670         3    15.20           2
#
#     Power  Price  Seats  Transmission  Year
# 0   58.16   1.75    5.0             1  2010
# 1  126.20  12.50    5.0             1  2015
# 2   88.70   4.50    5.0             1  2011
# 3   88.76   6.00    7.0             1  2012
# 4  140.80  17.74    5.0             0  2013

# %%
count=0
for i in df3['Power']:
    
    if(i==0):
        df3.drop([count],axis=0,inplace=True)
    count+=1
# Out:
# C:\Users\manavgakhar\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df3.head()
# Out:
#    Engine  Fuel_Type  Kilometers_Driven  Location  Mileage  Owner_Type  \
# 0     998          0              72000         9    26.60           0
# 1    1582          1              41000        10    19.67           0
# 2    1199          3              46000         2    18.20           0
# 3    1248          1              87000         2    20.77           0
# 4    1968          1              40670         3    15.20           2
#
#     Power  Price  Seats  Transmission  Year
# 0   58.16   1.75    5.0             1  2010
# 1  126.20  12.50    5.0             1  2015
# 2   88.70   4.50    5.0             1  2011
# 3   88.76   6.00    7.0             1  2012
# 4  140.80  17.74    5.0             0  2013

# %%
df3['Year']=df3['Year']-2000
# Out:
# C:\Users\manavgakhar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#    Unnamed: 0                                       Name    Location  Year  \
# 0           0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1           1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2           2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3           3                       Toyota Etios Liva GD   Hyderabad  2012
# 4           4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
#
#        Power  Seats   New_Price
# ...

# %%
df3.head()
# Out:
#    Engine  Fuel_Type  Kilometers_Driven  Location  Mileage  Owner_Type  \
# 0     998          0              72000         9    26.60           0
# 1    1582          1              41000        10    19.67           0
# 2    1199          3              46000         2    18.20           0
# 3    1248          1              87000         2    20.77           0
# 4    1968          1              40670         3    15.20           2
#
#     Power  Price  Seats  Transmission  Year
# 0   58.16   1.75    5.0             1    10
# 1  126.20  12.50    5.0             1    15
# 2   88.70   4.50    5.0             1    11
# 3   88.76   6.00    7.0             1    12
# 4  140.80  17.74    5.0             0    13

# %%
sns.scatterplot(x='Year',y='Price',data=df3)
#The older the car gets, the lower the price is

# %%
sns.scatterplot(x='Location',y='Price',data=df3)

# %%
sns.heatmap(df3.corr())

# %%
sns.lmplot(x='Power',y='Price',data=df3)
#There is a direct correlation between prie and power

# %%
sns.jointplot(x='Engine',y='Price',data=df3,kind='reg')
#As the engine displacement increases, the price increases

# %%
df3.dropna(inplace=True)
# Out:
# C:\Users\manavgakhar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df3.columns
# Out:
# Index(['Engine', 'Fuel_Type', 'Kilometers_Driven', 'Location', 'Mileage',
#        'Owner_Type', 'Power', 'Price', 'Seats', 'Transmission', 'Year'],
#       dtype='object')

# %%
a=[]
for i in df3['Power']:
    a.append(float(i))
df3['Power']=a
# Out:
# C:\Users\manavgakhar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
import sklearn
from sklearn import preprocessing

# %%
df3.columns
# Out:
# Index(['Engine', 'Fuel_Type', 'Kilometers_Driven', 'Location', 'Mileage',
#        'Owner_Type', 'Power', 'Price', 'Seats', 'Transmission', 'Year'],
#       dtype='object')

# %%
x=df3[['Engine','Kilometers_Driven','Mileage','Power']]

# %%
x=sklearn.preprocessing.normalize(x,axis=1)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5872 entries, 0 to 6018
# Data columns (total 11 columns):
# Engine               5872 non-null int64
# Fuel_Type            5872 non-null int32
# Kilometers_Driven    5872 non-null int64
# Location             5872 non-null int32
# Mileage              5872 non-null float64
# Owner_Type           5872 non-null int32
# Power                5872 non-null float64
# Price                5872 non-null float64
# Seats                5872 non-null float64
# Transmission         5872 non-null int32
# Year                 5872 non-null int64
# dtypes: float64(4), int32(4), int64(3)
# memory usage: 458.8 KB

# %%
np.shape(x)
# Out:
# (5872, 4)

# %%
df4=pd.DataFrame(x)

# %%
df3.drop(['Engine','Kilometers_Driven','Mileage','Power'],axis=1,inplace=True)
# Out:
# C:\Users\manavgakhar\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df3=df3.join(df4)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
df3.head()
# Out:
#    Fuel_Type  Location  Owner_Type  Price  Seats  Transmission  Year  \
# 0          0         9           0   1.75    5.0             1    10
# 1          1        10           0  12.50    5.0             1    15
# 2          3         2           0   4.50    5.0             1    11
# 3          1         2           0   6.00    7.0             1    12
# 4          1         3           2  17.74    5.0             0    13
#
#           0         1         2         3
# 0  0.013860  0.999904  0.000369  0.000808
# 1  0.038556  0.999252  0.000479  0.003076
# 2  0.026056  0.999659  0.000396  0.001928
# 3  0.014343  0.999897  0.000239  0.001020
# 4  0.048333  0.998825  0.000373  0.003458

# %%
df3.dropna(inplace=True)
X=df3.drop('Price',axis=1)

# %%
y=df3['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred=model.predict(X_test)

# %%
sns.distplot(y_test-pred)

# %%
from sklearn import metrics

# %%
sklearn.metrics.r2_score(y_test,pred)
# Out:
# 0.45939625124801287

# %%
from sklearn.svm import SVR

# %%
model2=SVR(kernel='poly')

# %%
model2.fit(X_train,y_train)
# Out:
# C:\Users\manavgakhar\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='poly', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pred2=model2.predict(X_test)

# %%
sns.distplot(y_test-pred2)

# %%
sklearn.metrics.r2_score(y_test,pred2)
#A decent r2 score using SVM with poly kernel
# Out:
# 0.5942382866562832
